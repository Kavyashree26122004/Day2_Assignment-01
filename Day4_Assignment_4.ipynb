# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cancer.csv")
df.head()
# Out:
#    age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0    5          1           1          1          2          1       3
# 1    5          4           4          5          7         10       3
# 2    3          1           1          1          2          2       3
# 3    6          8           8          1          3          4       3
# 4    4          1           1          3          2          1       3
#
#    breast-quad  irradiat  Class
# 0            1         1      0
# 1            2         1      0
# 2            1         1      0
# 3            7         1      0
# 4            1         1      0

# %%
df.tail(15)
# Out:
#      age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 668    1          1           1          1          2          1       1
# 669    1          1           1          1          2          1       1
# 670    1          1           1          1          2          1       1
# 671    3          1           1          1          2          1       2
# 672    4          1           1          1          2          1       1
# 673    1          1           1          1          2          1       1
# 674    1          1           1          3          2          1       1
# 675    5         10          10          5          4          5       4
# 676    3          1           1          1          2          1       1
# 677    3          1           1          1          2          1       2
# 678    3          1           1          1          3          2       1
# 679    2          1           1          1          2          1       1
# ...

# %%
df.dtypes
# Out:
# age            int64
# menopause      int64
# tumor-size     int64
# inv-nodes      int64
# node-caps      int64
# deg-malig      int64
# breast         int64
# breast-quad    int64
# irradiat       int64
# Class          int64
# dtype: object

# %%
pd.unique(df['menopause'])
# Out:
# array([ 1,  4,  8, 10,  2,  3,  7,  5,  6,  9])

# %%
df = df.drop(['menopause'], axis=1)
df.head(5)
# Out:
#    age  tumor-size  inv-nodes  node-caps  deg-malig  breast  breast-quad  \
# 0    5           1          1          2          1       3            1
# 1    5           4          5          7         10       3            2
# 2    3           1          1          2          2       3            1
# 3    6           8          1          3          4       3            7
# 4    4           1          3          2          1       3            1
#
#    irradiat  Class
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0

# %%
df = df.rename(columns={"Person's_Age": "Person_Age", "tumor_size": "TumorSize", "Class": "Test_Result"})
df.head(5)
# Out:
#    Person_Age  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0           5           1          1          2          1       3
# 1           5           4          5          7         10       3
# 2           3           1          1          2          2       3
# 3           6           8          1          3          4       3
# 4           4           1          3          2          1       3
#
#    breast-quad  irradiat  Test_Result
# 0            1         1            0
# 1            2         1            0
# 2            1         1            0
# 3            7         1            0
# 4            1         1            0

# %%
df.shape
# Out:
# (433, 9)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 9)

# %%
df.count()
# Out:
# Person_Age     433
# tumor-size     433
# inv-nodes      433
# node-caps      433
# deg-malig      433
# breast         433
# breast-quad    433
# irradiat       433
# Test_Result    433
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Person_Age     0
# tumor-size     0
# inv-nodes      0
# node-caps      0
# deg-malig      0
# breast         0
# breast-quad    0
# irradiat       0
# Test_Result    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Person_Age', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig',
#        'breast', 'breast-quad', 'irradiat', 'Test_Result'],
#       dtype='object')

# %%
sns.boxplot(x=df['Person_Age'])
# Out:
# <Axes: xlabel='Person_Age'>

# %%
df.Person_Age.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("count of persons by age")
plt.ylabel('number of persons')
plt.xlabel('age');
